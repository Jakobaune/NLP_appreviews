# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
from utils import classify_sentiment, balance_by_min_class

df = pd.read_csv('../data/ai_apps_reviews_100000.csv')

display(df.head())
display(df.tail())
# Out:
#                                reviewId               userName  \
# 0  e4fa3d7f-e865-42c4-a239-85c5dd5ea8ff          Shimran Singh
# 1  0d8f8007-a36b-4ddd-94d9-9e0406895312            Umar Farooq
# 2  7120266f-1987-432b-a1c9-52ba91ee3ade       Ritesh bagmor Ji
# 3  07fd0c25-8ef3-491d-8006-0820e3f8ea3e              Ucha Boss
# 4  d1e1b022-9160-4dae-9827-1bdd15039868  Odonchimeg Odonchimeg
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                            very good and helpful 🥹      5              0
# 1                                               good      5              0
# ...

# %%
print(df['appName'].nunique())
print(df['appName'].value_counts())
# Out:
# 3
# appName
# ChatGPT    100000
# Gemini     100000
# Claude      33329
# Name: count, dtype: int64

# %%
print(df['score'].value_counts())
# Out:
# score
# 5    171565
# 1     23302
# 4     22844
# 3     10300
# 2      5318
# Name: count, dtype: int64

# %%
df['Sentiment'] = df['score'].apply(classify_sentiment)

sentiment_counts = df['Sentiment'].value_counts()
print(sentiment_counts)
# Out:
# Sentiment
# Positive    194409
# Negative     28620
# Neutral      10300
# Name: count, dtype: int64

# %%
df_balanced = balance_by_min_class(df, label_col='Sentiment', random_state=42)

print(f"Total rows: {len(df_balanced)}")
print(df_balanced['Sentiment'].value_counts())

df_balanced.to_csv('../data/ai_apps_reviews_BALANCED.csv', index=False)
# Out:
# Total rows: 30900
# Sentiment
# Negative    10300
# Neutral     10300
# Positive    10300
# Name: count, dtype: int64
